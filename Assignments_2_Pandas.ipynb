# %%
import pandas as pd

# %%
column_names = [ 'Class_Name','Left_Weight','Left_Distance','Right_Weight','Right_Distance']

# %%
df =  pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/balance-scale/balance-scale.data", names = column_names)

# %%
df
# Out:
#     Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %% [markdown]
# #Check the number of data points and features in the data.

# %%
df.shape
# Out:
# (625, 5)

# %%
df.head(10)
# Out:
#   Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance
# 0          B            1              1             1               1
# 1          R            1              1             1               2
# 2          R            1              1             1               3
# 3          R            1              1             1               4
# 4          R            1              1             1               5
# 5          R            1              1             2               1
# 6          R            1              1             2               2
# 7          R            1              1             2               3
# 8          R            1              1             2               4
# 9          R            1              1             2               5

# %%
df.tail(10)
# Out:
#     Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance
# 615          L            5              5             4               1
# 616          L            5              5             4               2
# 617          L            5              5             4               3
# 618          L            5              5             4               4
# 619          L            5              5             4               5
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5

# %% [markdown]
# #Find unique values for each column.

# %%
df['Class_Name'].unique()
# Out:
# array(['B', 'R', 'L'], dtype=object)

# %%
df['Class_Name'].nunique()
# Out:
# 3

# %%
df['Left_Weight'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Left_Weight'].nunique()
# Out:
# 5

# %%
df['Left_Distance'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Left_Distance'].nunique()
# Out:
# 5

# %%
df['Right_Weight'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Right_Weight'].nunique()
# Out:
# 5

# %%
df['Right_Distance'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Right_Distance'].nunique()
# Out:
# 5

# %% [markdown]
# #Check the data types of values in each column.

# %%
df.dtypes
# Out:
# Class_Name        object
# Left_Weight        int64
# Left_Distance      int64
# Right_Weight       int64
# Right_Distance     int64
# dtype: object

# %% [markdown]
# #Check basic statistics of data.

# %%
df.describe()
# Out:
#        Left_Weight  Left_Distance  Right_Weight  Right_Distance
# count   625.000000     625.000000    625.000000      625.000000
# mean      3.000000       3.000000      3.000000        3.000000
# std       1.415346       1.415346      1.415346        1.415346
# min       1.000000       1.000000      1.000000        1.000000
# 25%       2.000000       2.000000      2.000000        2.000000
# 50%       3.000000       3.000000      3.000000        3.000000
# 75%       4.000000       4.000000      4.000000        4.000000
# max       5.000000       5.000000      5.000000        5.000000

# %% [markdown]
# #Add a new column in the data.

# %%
df['Total_Weight'] = df.iloc[:,[1,3]].sum(axis = 1)

# %%
df
# Out:
#     Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_Weight
# 0               2
# 1               2
# 2               2
# ...

# %% [markdown]
# #Then drop this column just created.

# %%
#Alternate Method 

# def df['Total_Weight']

df = df.drop('Total_Weight', axis = 1)

# %%
df
# Out:
#     Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %% [markdown]
# #create a new column that has values found as a result of applying some operation on the existing columns

# %%
df['Total_Weight'] = df.iloc[:,[1,3]].sum(axis = 1)

# %%
df
# Out:
#     Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_Weight
# 0               2
# 1               2
# 2               2
# ...

# %%
df['Total_Distance'] = df.iloc[:,[2,4]].sum(axis = 1)

# %%
df
# Out:
#     Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_Weight  Total_Distance
# 0               2               2
# ...

# %% [markdown]
# #Access elements using loc and iloc.

# %%
df.shape
# Out:
# (625, 7)

# %%
df.iloc[1:5,[0,1]]
# Out:
#   Class_Name  Left_Weight
# 1          R            1
# 2          R            1
# 3          R            1
# 4          R            1

# %%
df.iloc[0]
# Out:
# Class_Name        B
# Left_Weight       1
# Left_Distance     1
# Right_Weight      1
# Right_Distance    1
# Total_Weight      2
# Total_Distance    2
# Name: 0, dtype: object

# %%
df.iloc[[1]]
# Out:
#   Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 1          R            1              1             1               2
#
#    Total_Weight  Total_Distance
# 1             2               3

# %%
df.iloc[0:2]
# Out:
#   Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 0          B            1              1             1               1
# 1          R            1              1             1               2
#
#    Total_Weight  Total_Distance
# 0             2               2
# 1             2               3

# %%
df.iloc[:]
# Out:
#     Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_Weight  Total_Distance
# 0               2               2
# ...

# %%
df.iloc[0,0]
# Out:
# 'B'

# %%
df.iloc[0,[1,3]]
# Out:
# Left_Weight     1
# Right_Weight    1
# Name: 0, dtype: object

# %%
df.iloc[[0],[1,3]]
# Out:
#    Left_Weight  Right_Weight
# 0            1             1

# %%
df.iloc[:,[2]]
# Out:
#      Left_Distance
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 620              5
# 621              5
# 622              5
# 623              5
# 624              5
#
# [625 rows x 1 columns]

# %%
df.head(2)
# Out:
#   Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 0          B            1              1             1               1
# 1          R            1              1             1               2
#
#    Total_Weight  Total_Distance
# 0             2               2
# 1             2               3

# %%
df.loc[0]
# Out:
# Class_Name        B
# Left_Weight       1
# Left_Distance     1
# Right_Weight      1
# Right_Distance    1
# Total_Weight      2
# Total_Distance    2
# Name: 0, dtype: object

# %%
df.loc[0,'Class_Name']
# Out:
# 'B'

# %%
df.loc[[1],['Class_Name','Total_Weight']]
# Out:
#   Class_Name  Total_Weight
# 1          R             2

# %%
df.loc[1:5,['Class_Name','Total_Distance']]
# Out:
#   Class_Name  Total_Distance
# 1          R               3
# 2          R               4
# 3          R               5
# 4          R               6
# 5          R               2

# %%
df.loc[1:4,'Class_Name':'Left_Distance']
# Out:
#   Class_Name  Left_Weight  Left_Distance
# 1          R            1              1
# 2          R            1              1
# 3          R            1              1
# 4          R            1              1

# %%
df.loc[df.Total_Distance >= 6, ['Class_Name']]
# Out:
#     Class_Name
# 4            R
# 9            R
# 14           R
# 19           R
# 24           R
# ..         ...
# 620          L
# 621          L
# 622          L
# 623          L
# 624          B
#
# [375 rows x 1 columns]

# %% [markdown]
# #Check if there are missing values. If yes, which column.

# %%
df.isnull().head()
# Out:
#    Class_Name  Left_Weight  Left_Distance  Right_Weight  Right_Distance  \
# 0       False        False          False         False           False
# 1       False        False          False         False           False
# 2       False        False          False         False           False
# 3       False        False          False         False           False
# 4       False        False          False         False           False
#
#    Total_Weight  Total_Distance
# 0         False           False
# 1         False           False
# 2         False           False
# 3         False           False
# 4         False           False

# %%
df.isnull().sum()
# Out:
# Class_Name        0
# Left_Weight       0
# Left_Distance     0
# Right_Weight      0
# Right_Distance    0
# Total_Weight      0
# Total_Distance    0
# dtype: int64

# %% [markdown]
# #Assignment_2 Compute_dict()

# %% [markdown]
# #Counting the frequencies in a list using dictionary in Python

# %%
def compute_dist(l1):

	# Creating an empty dictionary
	count = {}
	for item in l1:
		if (item in count):
			count[item] += 1
		else:
			count[item] = 1

	for key, value in count.items():
		print ("% d : % d"%(key, value))

if __name__ == "__main__":
	  l1 =[3, 4, 2, 1, 5, 1, 2, 4, 3, 4]

d1= compute_dist(l1)
# Out:
#  3 :  2
#  4 :  3
#  2 :  2
#  1 :  2
#  5 :  1
